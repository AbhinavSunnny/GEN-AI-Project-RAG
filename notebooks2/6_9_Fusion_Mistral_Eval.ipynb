# %%
# ============================================================
# FIX FAISS / OPENMP CRASH
# ============================================================

import os

os.environ["OMP_NUM_THREADS"] = "1"

os.environ["KMP_DUPLICATE_LIB_OK"] = "TRUE"

print(
    "OpenMP Fix Applied"
)
# Out:
# OpenMP Fix Applied

# %%
# ============================================================
# IMPORT REQUIRED LIBRARIES
# ============================================================

import pandas as pd

import pickle

from dotenv import load_dotenv

from langchain_openai import OpenAIEmbeddings

from langchain_community.vectorstores import FAISS

from langchain_ollama import ChatOllama

from rank_bm25 import BM25Okapi

from duckduckgo_search import DDGS

print(
    "Libraries Loaded Successfully"
)
# Out:
# /var/folders/vq/9swrpcvn7sl3cb_pcdyf9r3h0000gn/T/ipykernel_3629/661869527.py:13: DeprecationWarning: `langchain-community` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-community/issues/674 for details and migration guidance toward standalone integration packages.
#   from langchain_community.vectorstores import FAISS
# Libraries Loaded Successfully

# %%
# ============================================================
# LOAD ENVIRONMENT VARIABLES
# ============================================================

load_dotenv()

print(
    "Environment Variables Loaded"
)
# Out:
# Environment Variables Loaded

# %%
# ============================================================
# LOAD EVALUATION DATASET
# ============================================================

eval_df = pd.read_csv(
    "../notebooks/evaluation_dataset.csv"
)

print(
    "Rows:",
    len(eval_df)
)

eval_df.head()
# Out:
# Rows: 1000
#                                                query  \
# 0  solar observatory aims to provide better under...
# 1                 mary j bliges new album my life ii
# 2  germany coach joachim low claims spain are fav...
# 3  presidential historians weigh in on how histor...
# 4  chinas gold medal gymnasts cleared of competin...
#
#                                              article  \
# 0  cnn nasa has postponed for one day the schedul...
# 1  cnn seventeen years after the release of her b...
# 2  cnn germany coach joachim low has tried to lif...
# 3  cnn with record low approval ratings and inten...
# 4  cnn chinas olympic gold medal gymnasts have be...
#
#                                    reference_summary
# 0  solar observatory aims to provide better under...
# 1  mary j bliges new album my life ii is a follow...
# 2  germany coach joachim low claims spain are fav...
# 3  presidential historians weigh in on how histor...
# 4  chinas gold medal gymnasts cleared of competin...

# %%
# ============================================================
# LOAD EMBEDDINGS
# ============================================================

embeddings = OpenAIEmbeddings(

    model="text-embedding-3-small"

)

print(
    "Embeddings Loaded Successfully"
)
# Out:
# Embeddings Loaded Successfully

# %%
# ============================================================
# LOAD FAISS
# ============================================================

vector_store = FAISS.load_local(

    "../notebooks/faiss_20k",

    embeddings,

    allow_dangerous_deserialization=True

)

print(
    "FAISS Loaded Successfully"
)
# Out:
# FAISS Loaded Successfully

# %%
# ============================================================
# LOAD CHUNKS
# ============================================================

with open(

    "../notebooks/all_chunks.pkl",

    "rb"

) as f:

    all_chunks = pickle.load(
        f
    )

print(
    "Chunks Loaded:",
    len(all_chunks)
)
# Out:
# Chunks Loaded: 160571

# %%
# ============================================================
# TOKENIZE CHUNKS
# ============================================================

tokenized_chunks = [

    chunk.lower().split()

    for chunk in all_chunks

]

print(
    "Tokenization Completed"
)
# Out:
# Tokenization Completed

# %%
# ============================================================
# LOAD BM25
# ============================================================

bm25 = BM25Okapi(
    tokenized_chunks
)

print(
    "BM25 Loaded Successfully"
)
# Out:
# BM25 Loaded Successfully

# %%
# ============================================================
# WEB SEARCH FUNCTION
# ============================================================

def web_search(

    query,

    max_results=5

):

    results = []

    with DDGS() as ddgs:

        search_results = list(

            ddgs.text(

                query,

                max_results=max_results

            )

        )

    for item in search_results:

        results.append(

            item["body"]

        )

    return results

# %%
# ============================================================
# LOAD MISTRAL
# ============================================================

llm = ChatOllama(

    model="mistral",

    temperature=0

)

print(
    "Mistral Loaded Successfully"
)
# Out:
# Mistral Loaded Successfully

# %%
# ============================================================
# RESET RESULTS
# ============================================================

results = []

print(
    "Results Reset Successfully"
)
# Out:
# Results Reset Successfully

# %%
# ============================================================
# FUSION MISTRAL EVALUATION PIPELINE
# ============================================================

for idx, row in eval_df.iterrows():

    if idx >= 25:
        break

    print(
        f"Processing Row {idx+1}/25"
    )

    query = str(
        row["query"]
    )

    reference_summary = str(
        row["reference_summary"]
    )

    # ========================================================
    # DENSE RETRIEVAL
    # ========================================================

    dense_docs = vector_store.similarity_search(

        query,

        k=5

    )

    dense_texts = [

        doc.page_content

        for doc in dense_docs

    ]

    # ========================================================
    # SPARSE RETRIEVAL
    # ========================================================

    tokenized_query = query.lower().split()

    sparse_indices = bm25.get_top_n(

        tokenized_query,

        list(
            range(
                len(all_chunks)
            )
        ),

        n=5

    )

    sparse_docs = [

        all_chunks[idx]

        for idx in sparse_indices

    ]

    # ========================================================
    # WEB SEARCH
    # ========================================================

    web_docs = web_search(

        query,

        max_results=5

    )

    # ========================================================
    # FUSION
    # ========================================================

    fusion_docs = (

        dense_texts

        +

        sparse_docs

        +

        web_docs

    )

    # ========================================================
    # CONTEXT
    # ========================================================

    context = "\n\n".join(
        fusion_docs
    )

    # ========================================================
    # PROMPT
    # ========================================================

    prompt = f"""

    You are a helpful AI assistant.

    Use ONLY the provided context.

    Context:

    {context}

    Question:

    {query}

    Answer:

    """

    # ========================================================
    # GENERATE RESPONSE
    # ========================================================

    response = llm.invoke(
        prompt
    )

    answer = response.content

    # ========================================================
    # STORE RESULTS
    # ========================================================

    results.append({

        "pipeline":
        "Fusion Mistral",

        "model":
        "Mistral",

        "retrieval_method":
        "Fusion",

        "query":
        query,

        "reference_summary":
        reference_summary,

        "generated_answer":
        answer

    })

print(
    "\nFusion Mistral Evaluation Completed"
)
# Out:
# Processing Row 1/25
# /var/folders/vq/9swrpcvn7sl3cb_pcdyf9r3h0000gn/T/ipykernel_3629/812884497.py:15: RuntimeWarning: This package (`duckduckgo_search`) has been renamed to `ddgs`! Use `pip install ddgs` instead.
#   with DDGS() as ddgs:
# Processing Row 2/25
# /var/folders/vq/9swrpcvn7sl3cb_pcdyf9r3h0000gn/T/ipykernel_3629/812884497.py:15: RuntimeWarning: This package (`duckduckgo_search`) has been renamed to `ddgs`! Use `pip install ddgs` instead.
#   with DDGS() as ddgs:
# Processing Row 3/25
# /var/folders/vq/9swrpcvn7sl3cb_pcdyf9r3h0000gn/T/ipykernel_3629/812884497.py:15: RuntimeWarning: This package (`duckduckgo_search`) has been renamed to `ddgs`! Use `pip install ddgs` instead.
#   with DDGS() as ddgs:
# Processing Row 4/25
# /var/folders/vq/9swrpcvn7sl3cb_pcdyf9r3h0000gn/T/ipykernel_3629/812884497.py:15: RuntimeWarning: This package (`duckduckgo_search`) has been renamed to `ddgs`! Use `pip install ddgs` instead.
#   with DDGS() as ddgs:
# Processing Row 5/25
# /var/folders/vq/9swrpcvn7sl3cb_pcdyf9r3h0000gn/T/ipykernel_3629/812884497.py:15: RuntimeWarning: This package (`duckduckgo_search`) has been renamed to `ddgs`! Use `pip install ddgs` instead.
#   with DDGS() as ddgs:
# Processing Row 6/25
# /var/folders/vq/9swrpcvn7sl3cb_pcdyf9r3h0000gn/T/ipykernel_3629/812884497.py:15: RuntimeWarning: This package (`duckduckgo_search`) has been renamed to `ddgs`! Use `pip install ddgs` instead.
#   with DDGS() as ddgs:
# Processing Row 7/25
# /var/folders/vq/9swrpcvn7sl3cb_pcdyf9r3h0000gn/T/ipykernel_3629/812884497.py:15: RuntimeWarning: This package (`duckduckgo_search`) has been renamed to `ddgs`! Use `pip install ddgs` instead.
#   with DDGS() as ddgs:
# Processing Row 8/25
# /var/folders/vq/9swrpcvn7sl3cb_pcdyf9r3h0000gn/T/ipykernel_3629/812884497.py:15: RuntimeWarning: This package (`duckduckgo_search`) has been renamed to `ddgs`! Use `pip install ddgs` instead.
#   with DDGS() as ddgs:
# Processing Row 9/25
# /var/folders/vq/9swrpcvn7sl3cb_pcdyf9r3h0000gn/T/ipykernel_3629/812884497.py:15: RuntimeWarning: This package (`duckduckgo_search`) has been renamed to `ddgs`! Use `pip install ddgs` instead.
#   with DDGS() as ddgs:
# Processing Row 10/25
# /var/folders/vq/9swrpcvn7sl3cb_pcdyf9r3h0000gn/T/ipykernel_3629/812884497.py:15: RuntimeWarning: This package (`duckduckgo_search`) has been renamed to `ddgs`! Use `pip install ddgs` instead.
#   with DDGS() as ddgs:
# Processing Row 11/25
# /var/folders/vq/9swrpcvn7sl3cb_pcdyf9r3h0000gn/T/ipykernel_3629/812884497.py:15: RuntimeWarning: This package (`duckduckgo_search`) has been renamed to `ddgs`! Use `pip install ddgs` instead.
#   with DDGS() as ddgs:
# Processing Row 12/25
# /var/folders/vq/9swrpcvn7sl3cb_pcdyf9r3h0000gn/T/ipykernel_3629/812884497.py:15: RuntimeWarning: This package (`duckduckgo_search`) has been renamed to `ddgs`! Use `pip install ddgs` instead.
#   with DDGS() as ddgs:
# Processing Row 13/25
# /var/folders/vq/9swrpcvn7sl3cb_pcdyf9r3h0000gn/T/ipykernel_3629/812884497.py:15: RuntimeWarning: This package (`duckduckgo_search`) has been renamed to `ddgs`! Use `pip install ddgs` instead.
#   with DDGS() as ddgs:
# Processing Row 14/25
# /var/folders/vq/9swrpcvn7sl3cb_pcdyf9r3h0000gn/T/ipykernel_3629/812884497.py:15: RuntimeWarning: This package (`duckduckgo_search`) has been renamed to `ddgs`! Use `pip install ddgs` instead.
#   with DDGS() as ddgs:
# Processing Row 15/25
# /var/folders/vq/9swrpcvn7sl3cb_pcdyf9r3h0000gn/T/ipykernel_3629/812884497.py:15: RuntimeWarning: This package (`duckduckgo_search`) has been renamed to `ddgs`! Use `pip install ddgs` instead.
#   with DDGS() as ddgs:
# Processing Row 16/25
# /var/folders/vq/9swrpcvn7sl3cb_pcdyf9r3h0000gn/T/ipykernel_3629/812884497.py:15: RuntimeWarning: This package (`duckduckgo_search`) has been renamed to `ddgs`! Use `pip install ddgs` instead.
#   with DDGS() as ddgs:
# Processing Row 17/25
# /var/folders/vq/9swrpcvn7sl3cb_pcdyf9r3h0000gn/T/ipykernel_3629/812884497.py:15: RuntimeWarning: This package (`duckduckgo_search`) has been renamed to `ddgs`! Use `pip install ddgs` instead.
#   with DDGS() as ddgs:
# Processing Row 18/25
# /var/folders/vq/9swrpcvn7sl3cb_pcdyf9r3h0000gn/T/ipykernel_3629/812884497.py:15: RuntimeWarning: This package (`duckduckgo_search`) has been renamed to `ddgs`! Use `pip install ddgs` instead.
#   with DDGS() as ddgs:
# Processing Row 19/25
# /var/folders/vq/9swrpcvn7sl3cb_pcdyf9r3h0000gn/T/ipykernel_3629/812884497.py:15: RuntimeWarning: This package (`duckduckgo_search`) has been renamed to `ddgs`! Use `pip install ddgs` instead.
#   with DDGS() as ddgs:
# Processing Row 20/25
# /var/folders/vq/9swrpcvn7sl3cb_pcdyf9r3h0000gn/T/ipykernel_3629/812884497.py:15: RuntimeWarning: This package (`duckduckgo_search`) has been renamed to `ddgs`! Use `pip install ddgs` instead.
#   with DDGS() as ddgs:
# Processing Row 21/25
# /var/folders/vq/9swrpcvn7sl3cb_pcdyf9r3h0000gn/T/ipykernel_3629/812884497.py:15: RuntimeWarning: This package (`duckduckgo_search`) has been renamed to `ddgs`! Use `pip install ddgs` instead.
#   with DDGS() as ddgs:
# Processing Row 22/25
# /var/folders/vq/9swrpcvn7sl3cb_pcdyf9r3h0000gn/T/ipykernel_3629/812884497.py:15: RuntimeWarning: This package (`duckduckgo_search`) has been renamed to `ddgs`! Use `pip install ddgs` instead.
#   with DDGS() as ddgs:
# Processing Row 23/25
# /var/folders/vq/9swrpcvn7sl3cb_pcdyf9r3h0000gn/T/ipykernel_3629/812884497.py:15: RuntimeWarning: This package (`duckduckgo_search`) has been renamed to `ddgs`! Use `pip install ddgs` instead.
#   with DDGS() as ddgs:
# Processing Row 24/25
# /var/folders/vq/9swrpcvn7sl3cb_pcdyf9r3h0000gn/T/ipykernel_3629/812884497.py:15: RuntimeWarning: This package (`duckduckgo_search`) has been renamed to `ddgs`! Use `pip install ddgs` instead.
#   with DDGS() as ddgs:
# Processing Row 25/25
# /var/folders/vq/9swrpcvn7sl3cb_pcdyf9r3h0000gn/T/ipykernel_3629/812884497.py:15: RuntimeWarning: This package (`duckduckgo_search`) has been renamed to `ddgs`! Use `pip install ddgs` instead.
#   with DDGS() as ddgs:
# Fusion Mistral Evaluation Completed

# %%
# ============================================================
# CREATE RESULTS DATAFRAME
# ============================================================

results_df = pd.DataFrame(
    results
)

print(
    "Total Records:",
    len(results_df)
)

results_df.head()
# Out:
# Total Records: 25
#          pipeline    model retrieval_method  \
# 0  Fusion Mistral  Mistral           Fusion
# 1  Fusion Mistral  Mistral           Fusion
# 2  Fusion Mistral  Mistral           Fusion
# 3  Fusion Mistral  Mistral           Fusion
# 4  Fusion Mistral  Mistral           Fusion
#
#                                                query  \
# 0  solar observatory aims to provide better under...
# 1                 mary j bliges new album my life ii
# 2  germany coach joachim low claims spain are fav...
# 3  presidential historians weigh in on how histor...
# 4  chinas gold medal gymnasts cleared of competin...
#
#                                    reference_summary  \
# 0  solar observatory aims to provide better under...
# 1  mary j bliges new album my life ii is a follow...
# 2  germany coach joachim low claims spain are fav...
# 3  presidential historians weigh in on how histor...
# 4  chinas gold medal gymnasts cleared of competin...
#
#                                     generated_answer
# 0   Solar observatory aims to provide better unde...
# 1   Mary J Blige's new album, "My Life II," is a ...
# 2   Yes, according to Germany coach Joachim Low, ...
# 3   presidential historians predict that history ...
# 4   underage, according to the International Gymn...

# %%
# ============================================================
# DATAFRAME INFO
# ============================================================

results_df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   pipeline           25 non-null     str
#  1   model              25 non-null     str
#  2   retrieval_method   25 non-null     str
#  3   query              25 non-null     str
#  4   reference_summary  25 non-null     str
#  5   generated_answer   25 non-null     str
# dtypes: str(6)
# memory usage: 16.4 KB

# %%
# ============================================================
# CHECK NULL VALUES
# ============================================================

results_df.isnull().sum()
# Out:
# pipeline             0
# model                0
# retrieval_method     0
# query                0
# reference_summary    0
# generated_answer     0
# dtype: int64

# %%
# ============================================================
# MANUAL VALIDATION
# ============================================================

results_df[
    [
        "query",
        "reference_summary",
        "generated_answer"
    ]
]
# Out:
#                                                 query  \
# 0   solar observatory aims to provide better under...
# 1                  mary j bliges new album my life ii
# 2   germany coach joachim low claims spain are fav...
# 3   presidential historians weigh in on how histor...
# 4   chinas gold medal gymnasts cleared of competin...
# 5     critics and viewers see stewart as victor after
# 6       bahr idriss abu garda faces charges in deaths
# 7        south africa beat cohosts india in world cup
# 8       rudy ruiz its become unfashionable to have an
# 9     fabio cannavaro is to join the italian national
# 10       new two of the arrested were responsible for
# 11     april 9 elections will determine the makeup of
# 12               oil was bound for us and nato forces
# 13       incubus brandon boyd has been indulging in a
# 14  in leogane haiti earthquake victims still need...
# 15  ban kimoon elected eighth un secretarygeneral ...
# 16   portugal defender bruno alves to have medical at
# 17  in lahores red light district iqbal hussain mocks
# 18            a doctor inserts a needle into the back
# 19  proposal calls for using maximumsecurity priso...
# 20  bronx woman charged with murder robbery police...
# 21  troubled singer found not guilty of hitting woman
# 22  documents posted on wikileaksorg include possi...
# 23    onefourth of all children are bullied red flags
# 24      a new group releases a commercial in response
#
#                                     reference_summary  \
# 0   solar observatory aims to provide better under...
# 1   mary j bliges new album my life ii is a follow...
# 2   germany coach joachim low claims spain are fav...
# 3   presidential historians weigh in on how histor...
# 4   chinas gold medal gymnasts cleared of competin...
# 5   critics and viewers see stewart as victor afte...
# 6   bahr idriss abu garda faces charges in deaths ...
# 7   south africa beat cohosts india in world cup c...
# 8   rudy ruiz its become unfashionable to have an ...
# 9   fabio cannavaro is to join the italian nationa...
# 10  new two of the arrested were responsible for p...
# 11  april 9 elections will determine the makeup of...
# 12  oil was bound for us and nato forces in afghan...
# 13  incubus brandon boyd has been indulging in a l...
# 14  in leogane haiti earthquake victims still need...
# 15  ban kimoon elected eighth un secretarygeneral ...
# 16  portugal defender bruno alves to have medical ...
# 17  in lahores red light district iqbal hussain mo...
# 18  a doctor inserts a needle into the back of the...
# 19  proposal calls for using maximumsecurity priso...
# 20  bronx woman charged with murder robbery police...
# 21  troubled singer found not guilty of hitting wo...
# 22  documents posted on wikileaksorg include possi...
# 23  onefourth of all children are bullied red flag...
# 24  a new group releases a commercial in response ...
#
#                                      generated_answer
# 0    Solar observatory aims to provide better unde...
# 1    Mary J Blige's new album, "My Life II," is a ...
# 2    Yes, according to Germany coach Joachim Low, ...
# 3    presidential historians predict that history ...
# 4    underage, according to the International Gymn...
# 5    critics and viewers see Jon Stewart as the vi...
# 6    Yes, Bahr Idriss Abu Garda faces charges for ...
# 7    Yes, South Africa beat cohosts India in the W...
# 8    According to the provided context, Rudy Ruiz ...
# 9    Yes, Fabio Cannavaro is to join the Italian n...
# 10   new two of the arrested were responsible for ...
# 11   The April 9 elections will determine the make...
# 12   Yes, the context indicates that oil was bound...
# 13   Incubus's Brandon Boyd has been indulging in ...
# 14   Yes, in Leogane, Haiti, earthquake victims st...
# 15   Yes, Ban Ki-moon was elected as the 8th Secre...
# 16                       Zenit St. Petersburg, Russia
# 17   Yes, in Lahore's red light district, Iqbal Hu...
# 18   A doctor can insert a needle into the back of...
# 19   Yes, the proposal calls for using a maximum s...
# 20   Yes, the context indicates that a Bronx woman...
# 21   Amy Winehouse, the troubled singer, was found...
# 22   Possible attacks by insurgents using heatseek...
# 23   According to the provided context, an estimat...
# 24   Yes, a new group (KATSEYE) released a commerc...

# %%
# ============================================================
# SAVE RESULTS
# ============================================================

results_df.to_csv(

    "fusion_mistral_eval.csv",

    index=False

)

print(
    "Fusion Mistral Evaluation Results Saved Successfully"
)
# Out:
# Fusion Mistral Evaluation Results Saved Successfully

# %%
# ============================================================
# VERIFY SAVED FILE
# ============================================================

saved_df = pd.read_csv(
    "fusion_mistral_eval.csv"
)

print(
    saved_df.shape
)

saved_df.head()
# Out:
# (25, 6)
#          pipeline    model retrieval_method  \
# 0  Fusion Mistral  Mistral           Fusion
# 1  Fusion Mistral  Mistral           Fusion
# 2  Fusion Mistral  Mistral           Fusion
# 3  Fusion Mistral  Mistral           Fusion
# 4  Fusion Mistral  Mistral           Fusion
#
#                                                query  \
# 0  solar observatory aims to provide better under...
# 1                 mary j bliges new album my life ii
# 2  germany coach joachim low claims spain are fav...
# 3  presidential historians weigh in on how histor...
# 4  chinas gold medal gymnasts cleared of competin...
#
#                                    reference_summary  \
# 0  solar observatory aims to provide better under...
# 1  mary j bliges new album my life ii is a follow...
# 2  germany coach joachim low claims spain are fav...
# 3  presidential historians weigh in on how histor...
# 4  chinas gold medal gymnasts cleared of competin...
#
#                                     generated_answer
# 0   Solar observatory aims to provide better unde...
# 1   Mary J Blige's new album, "My Life II," is a ...
# 2   Yes, according to Germany coach Joachim Low, ...
# 3   presidential historians predict that history ...
# 4   underage, according to the International Gymn...

# %%
# ============================================================
# FINAL SUMMARY
# ============================================================

print(
    "Pipeline : Fusion Mistral"
)

print(
    "Rows Evaluated :",
    len(saved_df)
)

print(
    "Output File : fusion_mistral_eval.csv"
)

print(
    "Evaluation Completed Successfully"
)
# Out:
# Pipeline : Fusion Mistral
# Rows Evaluated : 25
# Output File : fusion_mistral_eval.csv
# Evaluation Completed Successfully
